# %% [markdown]
# <a href="https://colab.research.google.com/github/UriVallejoFernandez/Programacion/blob/main/_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df =pd.read_csv("Unoosa - Full 1 (3).csv")

df
# Out:
#      Unnamed: 0 International Designator National Designator  \
# 0           NaN                2019-097A                 NaN
# 1           NaN              [2019-096C]       3538-2019-021
# 2           NaN              [2019-096B]       3537-2019-021
# 3           NaN              [2019-096A]       3536-2019-021
# 4           NaN              [2019-096E]                 NaN
# ..          ...                      ...                 ...
# 581         NaN                2019-002F                 NaN
# 582         NaN                2019-002B                 NaN
# 583         NaN                2019-002G                 NaN
# 584         NaN                2019-002A                 NaN
# 585         NaN                2019-001A                 NaN
#
#     Name of Space Object                 State Date of Launch GSO Location  \
# 0                  SJ 20                 China     2019-12-27          NaN
# 1         Gonets M No.26    Russian Federation     2019-12-27          NaN
# 2         Gonets M No.25    Russian Federation     2019-12-27          NaN
# 3         Gonets M No.24    Russian Federation     2019-12-27          NaN
# 4       [BLITS M/DM R/B]  [Russian Federation]   [2019-12-26]          NaN
# ..                   ...                   ...            ...          ...
# 581          Iridium 172                   USA     2019-01-11          NaN
# 582          Iridium 176                   USA     2019-01-11          NaN
# 583          Iridium 175                   USA     2019-01-11          NaN
# 584          Iridium 180                   USA     2019-01-11          NaN
# 585          Chinasat 2D                 China     2019-01-10          NaN
#
#     UN Registered Registration Document Other Documents      Status  \
# 0             Yes       ST/SG/SER.E/948             NaN      in GSO
# 1             Yes       ST/SG/SER.E/925             NaN    in orbit
# 2             Yes       ST/SG/SER.E/925             NaN    in orbit
# 3             Yes       ST/SG/SER.E/925             NaN    in orbit
# 4              No                   NaN             NaN  [in orbit]
# ..            ...                   ...             ...         ...
# 581           Yes       ST/SG/SER.E/924             NaN    in orbit
# 582           Yes       ST/SG/SER.E/924             NaN    in orbit
# 583           Yes       ST/SG/SER.E/924             NaN    in orbit
# 584           Yes       ST/SG/SER.E/924             NaN    in orbit
# 585           Yes       ST/SG/SER.E/948             NaN      in GSO
#
#     Date of Decay or Change  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 581                     NaN
# 582                     NaN
# 583                     NaN
# 584                     NaN
# 585                     NaN
#
#                               Function of Space Object  \
# 0                      Broadcasting and communications
# 1    Work on a low-orbit satellite communications s...
# 2    Work on a low-orbit satellite communications s...
# 3    Work on a low-orbit satellite communications s...
# 4                                               ------
# ..                                                 ...
# 581  Spacecraft engaged in practical applications a...
# 582  Spacecraft engaged in practical applications a...
# 583  Spacecraft engaged in practical applications a...
# 584  Spacecraft engaged in practical applications a...
# 585  Communications and broadcasting satellite to p...
#
#                                  Secretariat`s Remarks External website
# 0                                               ------              NaN
# 1              Date of launch is 2019-12-26 using UTC.              NaN
# 2              Date of launch is 2019-12-26 using UTC.              NaN
# 3              Date of launch is 2019-12-26 using UTC.              NaN
# 4    Not registered with the United Nations. Report...              NaN
# ..                                                 ...              ...
# 581                                             ------              NaN
# 582                                             ------              NaN
# 583                                             ------              NaN
# 584                                             ------              NaN
# 585                                             ------              NaN
#
# [586 rows x 15 columns]

# %%
n2 = df["State"].str.contains("Russian Federation") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 30

# %%
n2 = df["State"].str.contains("China") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 82

# %%
n2 = df["State"].str.contains("USA") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 362

# %%
n2 = df["State"].str.contains("ESA") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 2

# %%
n2 = df["State"].str.contains("ESA") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 2

# %%
n2 = df["Status"].str.contains("in orbit") #Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 201

# %%
n2 = df["Status"].str.contains("decayed")#Puc fer els true o false en cada cas
n2.value_counts() #suma els true o false i els separa en dues filesamb el resultat
n2[n2==True].count().sum() #fa el sumatori dels true
# Out:
# 253

# %%
df2 = df.loc[df['International Designator'].str.contains('2019-092F')] #localitzar linia del satèl·lit
df2["Date of Decay or Change"] #mostrar columna del decay
# Out:
# 19    [2024-05-22]
# Name: Date of Decay or Change, dtype: object
