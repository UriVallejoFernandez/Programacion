# %% [markdown]
# <a href="https://colab.research.google.com/github/UriVallejoFernandez/Programacion/blob/main/Sensor_de_llum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd


df = pd.read_csv("Taula - Full 1.csv")
df
# Out:
#      Temps  Aula A-23  Aula A-14  Passadis
# 0        1        108         87         0
# 1        2        131        136         0
# 2        3         96         83         0
# 3        4        148        149         0
# 4        5         95         87         0
# ..     ...        ...        ...       ...
# 340    341         98         96       253
# 341    342        161         96       252
# 342    343        106         96       252
# 343    344        158         96       252
# 344    345        119         96       253
#
# [345 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Temps'].plot(kind='hist', bins=20, title='Temps')
# ...

# %%
import pandas as pd


df = pd.read_csv("Taula - Full 1.csv")


maximos = df.max()
minimos = df.min()
media = df.mean()

print("Máximos:")
print(maximos)
print("Mínimos:")
print(minimos)
print("Media:")
print(media)


df
# Out:
# Máximos:
# Temps        345
# Aula A-23    252
# Aula A-14    155
# Passadis     255
# dtype: int64
# Mínimos:
# Temps        1
# Aula A-23    0
# Aula A-14    0
# Passadis     0
# dtype: int64
# Media:
# Temps        173.000000
# Aula A-23    155.889855
# Aula A-14    104.669565
# Passadis     128.773913
# dtype: float64
#      Temps  Aula A-23  Aula A-14  Passadis
# 0        1        108         87         0
# 1        2        131        136         0
# 2        3         96         83         0
# 3        4        148        149         0
# 4        5         95         87         0
# ..     ...        ...        ...       ...
# 340    341         98         96       253
# 341    342        161         96       252
# 342    343        106         96       252
# 343    344        158         96       252
# 344    345        119         96       253
#
# [345 rows x 4 columns]
