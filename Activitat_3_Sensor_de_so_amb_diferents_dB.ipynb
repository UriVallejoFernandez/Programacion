# %% [markdown]
# <a href="https://colab.research.google.com/github/UriVallejoFernandez/Programacion/blob/main/Activitat_3_Sensor_de_so_amb_diferents_dB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd


df = pd.read_csv("Taula de so2 - Full 1.csv")
df
# Out:
#       Temps  Passadis  A23  A14
# 0         1        33   41   97
# 1         2        67   48  101
# 2         3        60   45   97
# 3         4        41   45   90
# 4         5        41   48   97
# ...     ...       ...  ...  ...
# 2993   2994        37   52  105
# 2994   2995        37   52   97
# 2995   2996        33   45  116
# 2996   2997        45   67  108
# 2997   2998        37   67  112
#
# [2998 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Temps'].plot(kind='hist', bins=20, title='Temps')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Passadis'].plot(kind='hist', bins=20, title='Passadis')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['A23'].plot(kind='hist', bins=20, title='A23')
# ...

# %%
import pandas as pd


df = pd.read_csv("Taula de so2 - Full 1.csv")


maximos = df.max()
minimos = df.min()
media = df.mean()

print("Máximos:")
print(maximos)
print("Mínimos:")
print(minimos)
print("Media:")
print(media)


df
# Out:
# Máximos:
# Temps        2998
# Passadis     5252
# A23          3341
# A14         10101
# dtype: int64
# Mínimos:
# Temps       1
# Passadis    3
# A23         2
# A14         3
# dtype: int64
# Media:
# Temps       1499.500000
# Passadis      50.180120
# A23           74.800867
# A14           49.410274
# dtype: float64
#       Temps  Passadis  A23  A14
# 0         1        33   41   97
# 1         2        67   48  101
# 2         3        60   45   97
# 3         4        41   45   90
# 4         5        41   48   97
# ...     ...       ...  ...  ...
# 2993   2994        37   52  105
# 2994   2995        37   52   97
# 2995   2996        33   45  116
# 2996   2997        45   67  108
# 2997   2998        37   67  112
#
# [2998 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...
