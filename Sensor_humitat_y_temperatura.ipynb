# %% [markdown]
# <a href="https://colab.research.google.com/github/UriVallejoFernandez/Programacion/blob/main/Sensor_humitat_y_temperatura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd


df = pd.read_csv("Full de càlcul sense títol - Full 1.csv")
df
# Out:
#     Temps: Cada 2 segons   A-23 Temperatura  A-23 Humitat  A-14 Temperatura  \
# 0                       1              22.0          38.0              20.0
# 1                       2              22.0          38.0              20.0
# 2                       3              22.0          38.0              20.0
# 3                       4              22.0          38.0              20.0
# 4                       5              22.0          38.0              20.0
# 5                       6              22.0          38.0              20.0
# 6                       7              22.0          38.0              20.0
# 7                       8              22.0          38.0              20.0
# 8                       9              22.0          39.0              20.0
# 9                      10              22.0          40.0              20.0
# 10                     11              22.0          39.0              20.0
# ...

# %%
import pandas as pd


df = pd.read_csv("Full de càlcul sense títol - Full 1.csv")


maximos = df.max()
minimos = df.min()
media = df.mean()

print("Máximos:")
print(maximos)
print("Mínimos:")
print(minimos)
print("Media:")
print(media)


df
# Out:
# Máximos:
# Temps: Cada 2 segons     40.0
# A-23 Temperatura         22.0
# A-23 Humitat             41.0
# A-14 Temperatura         20.0
# A-14 Humitat             50.0
# A-12 Temperatura         20.0
# A-12-Humitat             52.0
# Temperatura gimnàs       20.0
# Humitat gimnàs           62.0
# Temperatura passadis     23.0
# Humitat Passadis         48.0
# dtype: float64
# Mínimos:
# Temps: Cada 2 segons      1.0
# A-23 Temperatura         22.0
# A-23 Humitat             38.0
# A-14 Temperatura         20.0
# A-14 Humitat             50.0
# A-12 Temperatura         20.0
# A-12-Humitat             50.0
# Temperatura gimnàs       20.0
# Humitat gimnàs           61.0
# Temperatura passadis     23.0
# Humitat Passadis         47.0
# dtype: float64
# Media:
# Temps: Cada 2 segons     20.500
# A-23 Temperatura         22.000
# A-23 Humitat             38.675
# A-14 Temperatura         20.000
# A-14 Humitat             50.000
# A-12 Temperatura         20.000
# ...
